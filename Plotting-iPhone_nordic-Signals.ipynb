# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
from scipy import signal
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
# Out:
# 2023-08-09 14:55:30.922461: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Functions

# %%
def getData(cfileName):
    
    # Read the *.cfile which has each element in float32 format.
    data = np.fromfile(cfileName, dtype="float32")

    # Take each consecutive interleaved I sample and Q sample to create a single complex element.
    data = data[0::2] + 1j*data[1::2]
    #print("data type=", type(data))
    # Return the complex numpy array.
    return data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals/iPhone13/iPhone13_I/calender-app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals_iPhone13_I_Validate/iPhone13_I_(iii)/calendar-app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals_iPhone13_I_Validate/iPhone13_I_data1/calendar_app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals_iPhone13_I_Validate/iPhone13_I_data2/calendar_app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals_Location_oriented/iPhone13_Beer Sheve,Israel/calendar_app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals_Validate/iPhone13/iPhone13_I_(ii)/calendar_app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals/iPhone13/iPhone13_II/calender-app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals/iPhone13/iPhone13_III/calendar-app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals/iPhone14-Pro/iPhone14_pro_I(i)/calendar-app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals_iPhone14Pro_I_Validate/iPhone14_pro_I(ii)/calendar-app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals_iPhone14Pro_I_Validate/iPhone14Pro_I_(iii)/calendar-app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals_iPhone14Pro_I_Validate/iPhone14Pro_I(iv)/calendar-app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals_iPhone14Pro_I_Validate/iPhone14Pro_I(v)/calendar-app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals/iPhone13/iPhone13_I/gallery-app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals/iPhone13/iPhone13_II/gallery-app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals/iPhone13/iPhone13_III/gallery-app.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals/iPhone13/iPhone13_I/idle.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals/iPhone13/iPhone13_II/idle.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Smartphones/EM_Signals/iPhone13/iPhone13_III/idle.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-25(i)/BLINK_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-25(ii)/BLINK_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-25(iii)/BLINK_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-30(i)/BLINK_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-30(ii)/BLINK_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-30(iii)/BLINK_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-25(i)/Matrix_MUL_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-25(ii)/Matrix_MUL_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-25(iii)/Matrix_MUL_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-30(i)/Matrix_MUL_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-30(ii)/Matrix_MUL_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-30(iii)/Matrix_MUL_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-25(i)/IDLE_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-25(ii)/IDLE_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-25(iii)/IDLE_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-30(i)/IDLE_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-30(ii)/IDLE_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %%
data = getData("/Volumes/Transcend/PhD in Computing/Data Collection/Nordic/2.4GHz/Device-30(iii)/IDLE_new.cfile")
fig = plt.figure()
plt.psd(data, NFFT=1024, Fs=20e6)
plt.show()
del data

# %% [markdown]
# ### Loading an EM Trace and Plotting

# %% [markdown]
# #### Settings:

# %%
# number of samples per class
num_samp_per_class = 10000

# FFT size for the STFT operation (which is same as the feature vector size)
fft_size = feature_vector_size = 2048 #1024

# number of overlapping samples for the STFT operation
fft_overlap = 256

# %%
labels = ["audio-recording", "camera-photo", "camera-video", "email-app", "gallary-app"
          , "home-screen", "idle", "phone-app", "sms-app", "web-browser-app"]

# %% [markdown]
# #### Preparing the Data of Class 0

# %%
class_label = 0
data = getData("/home/asanka/Desktop/smartphone-EM-dataset-2020-11-23/galaxy-grand-prime/audio-recording.cfile")
f, t, Zxx = signal.stft(data, fs=20e6, nperseg=fft_size, noverlap=fft_overlap)
print(len(f))
print(len(t))
print(Zxx.shape)
del data
Zxx = Zxx.transpose()
X = Zxx[:num_samp_per_class]
y = np.full(num_samp_per_class, class_label)
del Zxx
print(X.shape)
print(y.shape)
# Out:
# /home/asanka/miniconda3/lib/python3.7/site-packages/scipy/signal/spectral.py:1812: UserWarning: Input data is complex, switching to return_onesided=False
#   warnings.warn('Input data is complex, switching to '
# 2048
# 57494
# (2048, 57494)
# (10000, 2048)
# (10000,)

# %% [markdown]
# #### Preparing the Data of Class 1

# %%
class_label = 1
data = getData("/home/asanka/Desktop/smartphone-EM-dataset-2020-11-23/galaxy-grand-prime/camera-photo.cfile")
f, t, Zxx = signal.stft(data, fs=20e6, nperseg=fft_size, noverlap=fft_overlap)
print(len(f))
print(len(t))
print(Zxx.shape)
del data
Zxx = Zxx.transpose()

X = np.concatenate((X, Zxx[:num_samp_per_class]), axis=0) 
y = np.concatenate((y, np.full(num_samp_per_class, class_label)), axis=0)
#X = Zxx[:num_samp_per_class]
#y = np.full(num_samp_per_class, class_label)
del Zxx
print(X.shape)
print(y.shape)
# Out:
# 2048
# 35695
# (2048, 35695)
# (20000, 2048)
# (20000,)

# %% [markdown]
# #### Preparing the Data of Class 2

# %%
class_label = 2
data = getData("/home/asanka/Desktop/smartphone-EM-dataset-2020-11-23/galaxy-grand-prime/camera-video.cfile")
f, t, Zxx = signal.stft(data, fs=20e6, nperseg=fft_size, noverlap=fft_overlap)
print(len(f))
print(len(t))
print(Zxx.shape)
del data
Zxx = Zxx.transpose()
X = np.concatenate((X, Zxx[:num_samp_per_class]), axis=0) 
y = np.concatenate((y, np.full(num_samp_per_class, class_label)), axis=0)
#X = Zxx[:num_samp_per_class]
#y = np.full(num_samp_per_class, class_label)
del Zxx
print(X.shape)
print(y.shape)
# Out:
# 2048
# 46156
# (2048, 46156)
# (30000, 2048)
# (30000,)

# %% [markdown]
# #### Preparing the Data of Class 3

# %%
class_label = 3
data = getData("/home/asanka/Desktop/smartphone-EM-dataset-2020-11-23/galaxy-grand-prime/email-app.cfile")
f, t, Zxx = signal.stft(data, fs=20e6, nperseg=fft_size, noverlap=fft_overlap)
print(len(f))
print(len(t))
print(Zxx.shape)
del data
Zxx = Zxx.transpose()
X = np.concatenate((X, Zxx[:num_samp_per_class]), axis=0) 
y = np.concatenate((y, np.full(num_samp_per_class, class_label)), axis=0)
#X = Zxx[:num_samp_per_class]
#y = np.full(num_samp_per_class, class_label)
del Zxx
print(X.shape)
print(y.shape)
# Out:
# 2048
# 33867
# (2048, 33867)
# (40000, 2048)
# (40000,)

# %% [markdown]
# #### Preparing the Data of Class 4

# %%
class_label = 4
data = getData("/home/asanka/Desktop/smartphone-EM-dataset-2020-11-23/galaxy-grand-prime/gallary-app.cfile")
f, t, Zxx = signal.stft(data, fs=20e6, nperseg=fft_size, noverlap=fft_overlap)
print(len(f))
print(len(t))
print(Zxx.shape)
del data
Zxx = Zxx.transpose()
X = np.concatenate((X, Zxx[:num_samp_per_class]), axis=0) 
y = np.concatenate((y, np.full(num_samp_per_class, class_label)), axis=0)
#X = Zxx[:num_samp_per_class]
#y = np.full(num_samp_per_class, class_label)
del Zxx
print(X.shape)
print(y.shape)
# Out:
# 2048
# 51787
# (2048, 51787)
# (50000, 2048)
# (50000,)

# %% [markdown]
# #### Preparing the Data of Class 5

# %%
class_label = 5
data = getData("/home/asanka/Desktop/smartphone-EM-dataset-2020-11-23/galaxy-grand-prime/home-screen.cfile")
f, t, Zxx = signal.stft(data, fs=20e6, nperseg=fft_size, noverlap=fft_overlap)
print(len(f))
print(len(t))
print(Zxx.shape)
del data
Zxx = Zxx.transpose()
X = np.concatenate((X, Zxx[:num_samp_per_class]), axis=0) 
y = np.concatenate((y, np.full(num_samp_per_class, class_label)), axis=0)
#X = Zxx[:num_samp_per_class]
#y = np.full(num_samp_per_class, class_label)
del Zxx
print(X.shape)
print(y.shape)
# Out:
# 2048
# 57494
# (2048, 57494)
# (40000, 2048)
# (40000,)

# %% [markdown]
# #### Preparing the Data of Class 6

# %%
class_label = 6
data = getData("/home/asanka/Desktop/smartphone-EM-dataset-2020-11-23/galaxy-grand-prime/idle.cfile")
f, t, Zxx = signal.stft(data, fs=20e6, nperseg=fft_size, noverlap=fft_overlap)
print(len(f))
print(len(t))
print(Zxx.shape)
del data
Zxx = Zxx.transpose()
X = np.concatenate((X, Zxx[:num_samp_per_class]), axis=0) 
y = np.concatenate((y, np.full(num_samp_per_class, class_label)), axis=0)
#X = Zxx[:num_samp_per_class]
#y = np.full(num_samp_per_class, class_label)
del Zxx
print(X.shape)
print(y.shape)
# Out:
# 2048
# 48350
# (2048, 48350)
# (70000, 2048)
# (70000,)

# %% [markdown]
# #### Preparing the Data of Class 7

# %%
class_label = 7
data = getData("/home/asanka/Desktop/smartphone-EM-dataset-2020-11-23/galaxy-grand-prime/phone-app.cfile")
f, t, Zxx = signal.stft(data, fs=20e6, nperseg=fft_size, noverlap=fft_overlap)
print(len(f))
print(len(t))
print(Zxx.shape)
del data
Zxx = Zxx.transpose()
X = np.concatenate((X, Zxx[:num_samp_per_class]), axis=0) 
y = np.concatenate((y, np.full(num_samp_per_class, class_label)), axis=0)
#X = Zxx[:num_samp_per_class]
#y = np.full(num_samp_per_class, class_label)
del Zxx
print(X.shape)
print(y.shape)
# Out:
# 2048
# 36280
# (2048, 36280)
# (80000, 2048)
# (80000,)

# %% [markdown]
# #### Preparing the Data of Class 8

# %%
class_label = 8
data = getData("/home/asanka/Desktop/smartphone-EM-dataset-2020-11-23/galaxy-grand-prime/sms-app.cfile")
f, t, Zxx = signal.stft(data, fs=20e6, nperseg=fft_size, noverlap=fft_overlap)
print(len(f))
print(len(t))
print(Zxx.shape)
del data
Zxx = Zxx.transpose()
X = np.concatenate((X, Zxx[:num_samp_per_class]), axis=0) 
y = np.concatenate((y, np.full(num_samp_per_class, class_label)), axis=0)
#X = Zxx[:num_samp_per_class]
#y = np.full(num_samp_per_class, class_label)
del Zxx
print(X.shape)
print(y.shape)
# Out:
# 2048
# 47961
# (2048, 47961)
# (90000, 2048)
# (90000,)

# %% [markdown]
# #### Preparing the Data of Class 9

# %%
class_label = 9
data = getData("/home/asanka/Desktop/smartphone-EM-dataset-2020-11-23/galaxy-grand-prime/web-browser-app.cfile")
f, t, Zxx = signal.stft(data, fs=20e6, nperseg=fft_size, noverlap=fft_overlap)
print(len(f))
print(len(t))
print(Zxx.shape)
del data
Zxx = Zxx.transpose()
X = np.concatenate((X, Zxx[:num_samp_per_class]), axis=0) 
y = np.concatenate((y, np.full(num_samp_per_class, class_label)), axis=0)
#X = Zxx[:num_samp_per_class]
#y = np.full(num_samp_per_class, class_label)
del Zxx
print(X.shape)
print(y.shape)
# Out:
# 2048
# 45132
# (2048, 45132)
# (100000, 2048)
# (100000,)

# %% [markdown]
# ### Building the Model

# %%
X = abs(X)

# scaling the features (only real part of the data can be used)
scaler = MinMaxScaler()
scaler.fit(X)
print(scaler.data_max_)
X = scaler.transform(X)
# Out:
# [0.02410565 0.01188891 0.00493838 ... 0.00238575 0.00480893 0.01469892]

# %% [markdown]
# ### Principal Component Analysis (PCA)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 100)

# %%
X = pca.fit_transform(X)

# %%
print(X.shape)
# Out:
# (100000, 100)

# %%
# Split data to train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %%
model = keras.models.Sequential()
model.add(keras.layers.Input(shape=(feature_vector_size,)))
#model.add(keras.layers.Input(shape=(100,)))

model.add(keras.layers.Dense(1400, activation="relu"))

model.add(keras.layers.Dense(800, activation="relu"))
model.add(keras.layers.Dense(500, activation="relu"))
model.add(keras.layers.Dense(200, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))

model.add(keras.layers.Dense(50, activation="relu"))
#model.add(keras.layers.Dense(10, activation="softmax"))
model.add(keras.layers.Dense(4, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1400)              2868600
# _________________________________________________________________
# dense_1 (Dense)              (None, 800)               1120800
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               400500
# _________________________________________________________________
# dense_3 (Dense)              (None, 200)               100200
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                5050
# _________________________________________________________________
# ...

# %%
opt = keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
#model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])

# %%
#history = model.fit(X_train, y_train, epochs=30, validation_data=(X_test, y_test))
#history = model.fit(X_train, y_train, epochs=30, validation_split=0.1)

checkpoint_cb = keras.callbacks.ModelCheckpoint("./3.Galaxy-Grand-Prime-Analysis-SELECTED-ACTIVITIES.h5", save_best_only=True)
history = model.fit(X_train, y_train, epochs=30, validation_split=0.2, callbacks=[checkpoint_cb])
# Out:
# Epoch 1/30
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-13-ac07b4504e3f> in <module>
#       3
#       4 checkpoint_cb = keras.callbacks.ModelCheckpoint("./3.Galaxy-Grand-Prime-Analysis-SELECTED-ACTIVITIES.h5", save_best_only=True)
# ----> 5 history = model.fit(X_train, y_train, epochs=30, validation_split=0.2, callbacks=[checkpoint_cb])
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ...

# %% [markdown]
# ### Plotting

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %% [markdown]
# ### Testing the Model

# %%
#model = keras.models.load_model("./3.Galaxy-Grand-Prime-Analysis.h5")
model = keras.models.load_model("./3.Galaxy-Grand-Prime-Analysis-SELECTED-ACTIVITIES.h5")

# %%
results = model.evaluate(X_test, y_test)
print("test loss, test acc:", results)
# Out:
# 32/32 [==============================] - 0s 8ms/step - loss: 5.9742e-04 - accuracy: 0.0000e+00
# test loss, test acc: [0.0005974198575131595, 0.0]

# %%
#y_pred = model.predict(X_test)
y_pred = model.predict_classes(X_test)
# Out:
# WARNING:tensorflow:From <ipython-input-83-2e172f00940a>:2: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
print(y_pred)
# Out:
# [9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9
#  9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9
#  9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9
#  9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9
#  9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9
#  9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9
#  9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9
#  9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9
#  9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9
#  9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9
#  9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9
#  9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9
# ...

# %%
print(y_pred[0])
# Out:
# 9

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1000]]
#               precision    recall  f1-score   support
#
#            9       1.00      1.00      1.00      1000
#
#     accuracy                           1.00      1000
#    macro avg       1.00      1.00      1.00      1000
# weighted avg       1.00      1.00      1.00      1000

# %% [markdown]
# ### Saving the Model

# %%
#model.save("./3.Galaxy-Grand-Prime-Analysis-SELECTED-ACTIVITIES.h5")
